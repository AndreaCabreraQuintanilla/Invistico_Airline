# %% [markdown]
# ### Pair II
# # Preprocesado

# %%
# Tratamiento de datos
# -----------------------------------------------------------------------
import numpy as np
import pandas as pd


# Gráficos
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns


# Estandarización variables numéricas y Codificación variables categóricas
# ------------------------------------------------------------------------------
from sklearn.preprocessing import StandardScaler

# Gestión datos desbalanceados
# ------------------------------------------------------------------------------
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler
from imblearn.combine import SMOTETomek

# Para separar los datos en train y test
# ------------------------------------------------------------------------------
from sklearn.model_selection import train_test_split

#  Gestión de warnings
# ------------------------------------------------------------------------------
import warnings
warnings.filterwarnings("ignore")

# Para poder ver todas las columnas del dataframe
# ------------------------------------------------
pd.options.display.max_columns = None

# Establecer la paleta de color de gráficas
# ==================================
qualitative_colors = sns.color_palette("Set2", 20)

# %% [markdown]
# Usando el mismo dataset que usatéis ayer, los objetivos de los ejercicios de hoy son:
# - Estandarizar las variables numéricas de vuestro set de datos
# - Codificar las variables categóricas. Recordad que tendréis que tener en cuenta si vuestras variables tienen orden o no.
# - Chequear si vuestros datos están balanceados. En caso de que no lo estén utilizad algunas de las herramientas aprendidas en la lección para balancearlos.
# - Guardad el dataframe con los cambios que habéis aplicado para utilizarlo en la siguiente lección.

# %%
df = pd.read_pickle("../data/Invistico_Airline_limpio_outliers_sin_tratar.pkl")
df.sample(2)
# Out:
#         satisfaccion  genero       cliente  edad              viaje     clase  \
# 101633    satisfecho  hombre  cliente leal    43  viaje de negocios  Business
# 68195   insatisfecho   mujer  cliente leal    53  viaje de negocios       Eco
#
#         distancia  asiento  puntualidad  comida_bebida  puerta_embarque  wifi  \
# 101633        367        2            2              5                2     4
# 68195         469        1            1              1                1     1
#
#         entretenimiento  asistencia_linea  reserva_linea  serv_a_bordo  \
# 101633                5                 5              4             4
# 68195                 4                 3              1             1
#
#         serv_habitaciones  gestion_equipaje  checkin  limpieza  \
# 101633                  4                 4        4         4
# 68195                   1                 1        3         1
#
#         embarque_linea  retraso_salida
# 101633               4               0
# 68195                1               0

# %% [markdown]
# ```Estandarización```

# %%
numericas = df.select_dtypes(include = np.number)
numericas.head()
# Out:
#    edad  distancia  asiento  puntualidad  comida_bebida  puerta_embarque  \
# 0    65        265        0            0              0                2
# 1    47       2464        0            0              0                3
# 2    15       2138        0            0              0                3
# 3    60        623        0            0              0                3
# 4    70        354        0            0              0                3
#
#    wifi  entretenimiento  asistencia_linea  reserva_linea  serv_a_bordo  \
# 0     2                4                 2              3             3
# 1     0                2                 2              3             4
# 2     2                0                 2              2             3
# 3     3                4                 3              1             1
# 4     4                3                 4              2             2
#
#    serv_habitaciones  gestion_equipaje  checkin  limpieza  embarque_linea  \
# 0                  0                 3        5         3               2
# 1                  4                 4        2         3               2
# 2                  3                 4        4         4               2
# 3                  0                 1        4         1               3
# 4                  0                 2        4         2               5
#
#    retraso_salida
# 0               0
# 1             310
# 2               0
# 3               0
# 4               0

# %%
df_num = df[["edad", "distancia", "retraso_salida"]]
df_num
# Out:
#         edad  distancia  retraso_salida
# 0         65        265               0
# 1         47       2464             310
# 2         15       2138               0
# 3         60        623               0
# 4         70        354               0
# ...      ...        ...             ...
# 129875    29       1731               0
# 129876    63       2087             174
# 129877    69       2320             155
# 129878    66       2450             193
# 129879    38       4307             185
#
# [129880 rows x 3 columns]

# %%
scaler = StandardScaler()

# %%
# ahora ya podemos ajustar nuestros datos.  

scaler.fit(df_num)

# transformamos los datos

X_escaladas = scaler.transform(df_num)

numericas_estandar = pd.DataFrame(X_escaladas, columns = df_num.columns)
numericas_estandar.head(2)
# Out:
#        edad  distancia  retraso_salida
# 0  1.691351  -1.671103       -0.386481
# 1  0.500820   0.469852        7.756204

# %%
df.drop(["edad", "distancia", "retraso_salida"], axis = 1, inplace= True)

# %%
# Unimos los df

df = pd.concat([df, numericas_estandar], axis = 1)
df.head()
# Out:
#   satisfaccion  genero       cliente           viaje     clase  asiento  \
# 0   satisfecho   mujer  cliente leal  viaje personal       Eco        0
# 1   satisfecho  hombre  cliente leal  viaje personal  Business        0
# 2   satisfecho   mujer  cliente leal  viaje personal       Eco        0
# 3   satisfecho   mujer  cliente leal  viaje personal       Eco        0
# 4   satisfecho   mujer  cliente leal  viaje personal       Eco        0
#
#    puntualidad  comida_bebida  puerta_embarque  wifi  entretenimiento  \
# 0            0              0                2     2                4
# 1            0              0                3     0                2
# 2            0              0                3     2                0
# 3            0              0                3     3                4
# 4            0              0                3     4                3
#
#    asistencia_linea  reserva_linea  serv_a_bordo  serv_habitaciones  \
# 0                 2              3             3                  0
# 1                 2              3             4                  4
# 2                 2              2             3                  3
# 3                 3              1             1                  0
# 4                 4              2             2                  0
#
#    gestion_equipaje  checkin  limpieza  embarque_linea      edad  distancia  \
# 0                 3        5         3               2  1.691351  -1.671103
# 1                 4        2         3               2  0.500820   0.469852
# 2                 4        4         4               2 -1.615680   0.152458
# 3                 1        4         1               3  1.360648  -1.322552
# 4                 2        4         2               5  2.022054  -1.584452
#
#    retraso_salida
# 0       -0.386481
# 1        7.756204
# 2       -0.386481
# 3       -0.386481
# 4       -0.386481

# %%
df["clase"].unique()
# Out:
# ['Eco', 'Business', 'Eco Plus']
# Categories (3, object): ['Business', 'Eco', 'Eco Plus']

# %% [markdown]
# ```Codificación con datos estandarizados```

# %%
fig, axes = plt.subplots(3, 1, figsize=(20, 10))
axes = axes.flat

for indice, columna in enumerate(numericas_estandar):
    sns.boxplot(x = df[columna], y = df["satisfaccion"], data = df, ax=axes[indice], palette = qualitative_colors);
plt.tight_layout()
#fig.delaxes(axes[-1])
plt.savefig("../graficas/02_prepro_boxplot_outliers.png")
plt.show();

# %% [markdown]
# Comprobamos con la gráfica boxplot que sí tienen orden.

# %% [markdown]
# ```Codificación con datos sin estandarizar```

# %%
# encoding de categóricas con orden

map_satisfaccion = {"satisfecho": 1, "insatisfecho": 0}
map_genero = {"hombre": 0, "mujer":1}
map_cliente = {"cliente leal": 0, "cliente desleal": 1}
map_viaje = {"viaje personal": 0, "viaje de negocios": 1}
map_clase = {"Eco": 0, "Business": 1, "Eco Plus": 2}


df["satisfaccion"] = df["satisfaccion"].map(map_satisfaccion)
df["genero"] = df["genero"].map(map_genero)
df["cliente"] = df["cliente"].map(map_cliente)
df["viaje"] = df["viaje"].map(map_viaje)
df["clase"] = df["clase"].map(map_clase)

# %% [markdown]
# ```Desbalanceo usando imblearn (SMOTE)```

# %%
# recordamos como están distribuidos los datos de vr

plt.figure(figsize=(8,5)) 

fig1 = sns.countplot(data = df, x = "satisfaccion",  palette= qualitative_colors,  edgecolor='black')
fig1.set(xticklabels=["insatisfecho", "satisfecho"]) 
plt.show();

# %%
# lo primero que hacemos es sacar el número de registros que tenemos para la clase minoritaria
num_minoritarios = df["satisfaccion"].value_counts()[1]
num_minoritarios
# Out:
# 71087

# %%
# para aplicar este método lo primero que tenemos que hacer es separar en X e y y en train y test como aprendimos en la lecciones de regresion lineal
y = df['satisfaccion']
X = df.drop('satisfaccion', axis=1)


#dividimos en sets de entrenamiento y test
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7)

# %%
# iniciamos el método
os_us = SMOTETomek()

# ajustamos el modelo
X_train_res, y_train_res = os_us.fit_resample(X_train, y_train)

# %%
y_train.value_counts()
# Out:
# satisfaccion
# 1    49793
# 0    41123
# Name: count, dtype: int64

# %%
y_train_res.value_counts()
# Out:
# satisfaccion
# 0    48886
# 1    48886
# Name: count, dtype: int64

# %%
# comprobemos como han quedado ahora las categorías después del ajuste

print (f"Satisfacción antes del ajuste \n {y_train.value_counts()}" )
print("..............................................................")
print (f"Distribución después del ajuste \n {y_train_res.value_counts()}")
# Out:
# Satisfacción antes del ajuste
#  satisfaccion
# 1    49793
# 0    41123
# Name: count, dtype: int64
# ..............................................................
# Distribución después del ajuste
#  satisfaccion
# 0    48886
# 1    48886
# Name: count, dtype: int64

# %%
df.to_pickle("../data/preprocesado_outliers_sin_tratar.pkl")
