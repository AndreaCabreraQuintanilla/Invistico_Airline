# %% [markdown]
# ### Pair VI
# # Random Forest

# %%
# Tratamiento de datos
# ------------------------------------------------------------------------------
import numpy as np
import pandas as pd
from tqdm import tqdm

# Gráficos
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Modelado y evaluación
# ------------------------------------------------------------------------------
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score , cohen_kappa_score, roc_curve,roc_auc_score
from sklearn.model_selection import GridSearchCV

# Configuración warnings
# ------------------------------------------------------------------------------
import warnings
warnings.filterwarnings('ignore')

# Establecer la paleta de color de gráficas
# ==================================
qualitative_colors = sns.color_palette("Set2", 20)

# Para poder ver todas las columnas del dataframe
# ------------------------------------------------
pd.options.display.max_columns = None

# %% [markdown]
# Hasta ahora hemos ajustado el modelo usando una Regresión Logística, pero como hemos aprendido, podemos usar el Random Forest en este tipo de problemas. Los objetivos de este pair programming:
# - Ajustad un modelo de Random Forest a nuestros datos.
# - Calculad las métricas a nuestro nuevo modelo.
# - Comparad las métricas con los modelos hechos hasta ahora. ¿Cuál es mejor?

# %%
df = pd.read_pickle("../data/metricas_sin_estand_con_outliers.pkl")
df.sample(2)
# Out:
#       satisfaccion genero cliente  edad viaje clase  distancia  asiento  \
# 22800            0      0       0    25     0     0       1595        3
# 14040            0      1       0    35     0     0       2493        2
#
#        puntualidad  comida_bebida  puerta_embarque  wifi  entretenimiento  \
# 22800            3              3                1     5                3
# 14040            4              2                3     4                2
#
#        asistencia_linea  reserva_linea  serv_a_bordo  serv_habitaciones  \
# 22800                 5              5             5                  2
# 14040                 4              4             4                  3
#
#        gestion_equipaje  checkin  limpieza  embarque_linea  retraso_salida
# 22800                 4        1         5               5               0
# 14040                 5        4         4               4             130

# %%
X1 = df.drop("satisfaccion", axis = 1)
y1 = df["satisfaccion"]

# %%
x_train, x_test, y_train, y_test = train_test_split(X1, y1, test_size = 0.2, random_state = 42)

# %%
param = {"max_depth": [37, 38, 39], 
        "max_features": [4, 5, 6],
        "min_samples_split": [10, 50],
        "min_samples_leaf": [10, 11],
        "n_estimators": [3]}

# %%
gs_rf = GridSearchCV(
            estimator=RandomForestClassifier(random_state=42), 
            param_grid= param,
            cv=10, 
            verbose=1)

# %%
gs_rf.fit(x_train, y_train)
# Out:
# Fitting 10 folds for each of 36 candidates, totalling 360 fits
# GridSearchCV(cv=10, estimator=RandomForestClassifier(random_state=42),
#              param_grid={'max_depth': [37, 38, 39], 'max_features': [4, 5, 6],
#                          'min_samples_leaf': [10, 11],
#                          'min_samples_split': [10, 50], 'n_estimators': [3]},
#              verbose=1)

# %%
bosque = gs_rf.best_estimator_
bosque
# Out:
# RandomForestClassifier(max_depth=37, max_features=6, min_samples_leaf=10,
#                        min_samples_split=50, n_estimators=3, random_state=42)

# %%
for arbol in tqdm(bosque.estimators_):
    fig = plt.figure(figsize=(20, 10))
    tree.plot_tree(arbol, feature_names= list(x_train.columns), filled = True)
    plt.show()
    break
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [02:44<?, ?it/s]

# %%
y_pred_test_rf = bosque.predict(x_test)
y_pred_train_rf = bosque.predict(x_train)

# %%
def metricas(clases_reales_test, clases_predichas_test, clases_reales_train, clases_predichas_train, modelo):
    
    # para el test
    accuracy_test = accuracy_score(clases_reales_test, clases_predichas_test)
    precision_test = precision_score(clases_reales_test, clases_predichas_test)
    recall_test = recall_score(clases_reales_test, clases_predichas_test)
    f1_test = f1_score(clases_reales_test, clases_predichas_test)
    kappa_test = cohen_kappa_score(clases_reales_test, clases_predichas_test)

    # para el train
    accuracy_train = accuracy_score(clases_reales_train, clases_predichas_train)
    precision_train = precision_score(clases_reales_train, clases_predichas_train)
    recall_train = recall_score(clases_reales_train, clases_predichas_train)
    f1_train = f1_score(clases_reales_train, clases_predichas_train)
    kappa_train = cohen_kappa_score(clases_reales_train, clases_predichas_train)
    

    
    df = pd.DataFrame({"accuracy": [accuracy_test, accuracy_train], 
                       "precision": [precision_test, precision_train],
                       "recall": [recall_test, recall_train], 
                       "f1": [f1_test, f1_train],
                       "kapppa": [kappa_test, kappa_train],
                       "set": ["test", "train"]})
    
    df["modelo"] = modelo
    return df

# %%
results_forest = metricas(y_test, y_pred_test_rf,y_train,  y_pred_train_rf, "Random Forest")
results_forest
# Out:
#    accuracy  precision    recall        f1    kapppa    set         modelo
# 0  0.944526   0.957261  0.941263  0.949194  0.888116   test  Random Forest
# 1  0.951215   0.964254  0.945796  0.954936  0.901770  train  Random Forest

# %%
results_tree = pd.read_pickle("../data/resultados_decision_tree_sin_estand_con_outliers.pkl")
results_tree
# Out:
#    accuracy  precision    recall        f1    kapppa    set  \
# 0  0.938405   0.944744  0.943291  0.944017  0.875559   test
# 1  1.000000   1.000000  1.000000  1.000000  1.000000  train
# 0  0.933670   0.944767  0.934130  0.939418  0.866139   test
# 1  0.941687   0.952718  0.939950  0.946291  0.882516  train
# 0  0.933670   0.944767  0.934130  0.939418  0.866139   test
# 1  0.941687   0.952718  0.939950  0.946291  0.882516  train
#
#                        modelo
# 0       Decission Tree Esta I
# 1       Decission Tree Esta I
# 0       Decision tree Esta II
# 1       Decision tree Esta II
# 0  Decision tree Sin Esta III
# 1  Decision tree Sin Esta III

# %%
df_todos_resultados = pd.concat([results_tree, results_forest], axis = 0).reset_index(drop=True)
df_todos_resultados
# Out:
#    accuracy  precision    recall        f1    kapppa    set  \
# 0  0.938405   0.944744  0.943291  0.944017  0.875559   test
# 1  1.000000   1.000000  1.000000  1.000000  1.000000  train
# 2  0.933670   0.944767  0.934130  0.939418  0.866139   test
# 3  0.941687   0.952718  0.939950  0.946291  0.882516  train
# 4  0.933670   0.944767  0.934130  0.939418  0.866139   test
# 5  0.941687   0.952718  0.939950  0.946291  0.882516  train
# 6  0.944526   0.957261  0.941263  0.949194  0.888116   test
# 7  0.951215   0.964254  0.945796  0.954936  0.901770  train
#
#                        modelo
# 0       Decission Tree Esta I
# 1       Decission Tree Esta I
# 2       Decision tree Esta II
# 3       Decision tree Esta II
# 4  Decision tree Sin Esta III
# 5  Decision tree Sin Esta III
# 6               Random Forest
# 7               Random Forest

# %%
df_todos_resultados.style.background_gradient(cmap= "Set2")
# Out:
# <style type="text/css">
# #T_0e0c6_row0_col0, #T_0e0c6_row0_col1, #T_0e0c6_row0_col3, #T_0e0c6_row0_col4, #T_0e0c6_row2_col0, #T_0e0c6_row2_col1, #T_0e0c6_row2_col2, #T_0e0c6_row2_col3, #T_0e0c6_row2_col4, #T_0e0c6_row3_col0, #T_0e0c6_row3_col2, #T_0e0c6_row3_col3, #T_0e0c6_row3_col4, #T_0e0c6_row4_col0, #T_0e0c6_row4_col1, #T_0e0c6_row4_col2, #T_0e0c6_row4_col3, #T_0e0c6_row4_col4, #T_0e0c6_row5_col0, #T_0e0c6_row5_col2, #T_0e0c6_row5_col3, #T_0e0c6_row5_col4, #T_0e0c6_row6_col2 {
#   background-color: #66c2a5;
#   color: #000000;
# }
# #T_0e0c6_row0_col2, #T_0e0c6_row3_col1, #T_0e0c6_row5_col1, #T_0e0c6_row6_col0, #T_0e0c6_row6_col1, #T_0e0c6_row6_col3, #T_0e0c6_row6_col4, #T_0e0c6_row7_col2 {
#   background-color: #fc8d62;
#   color: #f1f1f1;
# }
# #T_0e0c6_row1_col0, #T_0e0c6_row1_col1, #T_0e0c6_row1_col2, #T_0e0c6_row1_col3, #T_0e0c6_row1_col4 {
#   background-color: #b3b3b3;
#   color: #000000;
# }
# #T_0e0c6_row7_col0, #T_0e0c6_row7_col1, #T_0e0c6_row7_col3, #T_0e0c6_row7_col4 {
#   background-color: #8da0cb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0e0c6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0e0c6_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_0e0c6_level0_col1" class="col_heading level0 col1" >precision</th>
#       <th id="T_0e0c6_level0_col2" class="col_heading level0 col2" >recall</th>
#       <th id="T_0e0c6_level0_col3" class="col_heading level0 col3" >f1</th>
#       <th id="T_0e0c6_level0_col4" class="col_heading level0 col4" >kapppa</th>
#       <th id="T_0e0c6_level0_col5" class="col_heading level0 col5" >set</th>
#       <th id="T_0e0c6_level0_col6" class="col_heading level0 col6" >modelo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e0c6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0e0c6_row0_col0" class="data row0 col0" >0.938405</td>
#       <td id="T_0e0c6_row0_col1" class="data row0 col1" >0.944744</td>
#       <td id="T_0e0c6_row0_col2" class="data row0 col2" >0.943291</td>
#       <td id="T_0e0c6_row0_col3" class="data row0 col3" >0.944017</td>
#       <td id="T_0e0c6_row0_col4" class="data row0 col4" >0.875559</td>
#       <td id="T_0e0c6_row0_col5" class="data row0 col5" >test</td>
#       <td id="T_0e0c6_row0_col6" class="data row0 col6" >Decission Tree Esta I</td>
#     </tr>
#     <tr>
#       <th id="T_0e0c6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0e0c6_row1_col0" class="data row1 col0" >1.000000</td>
#       <td id="T_0e0c6_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_0e0c6_row1_col2" class="data row1 col2" >1.000000</td>
#       <td id="T_0e0c6_row1_col3" class="data row1 col3" >1.000000</td>
#       <td id="T_0e0c6_row1_col4" class="data row1 col4" >1.000000</td>
#       <td id="T_0e0c6_row1_col5" class="data row1 col5" >train</td>
#       <td id="T_0e0c6_row1_col6" class="data row1 col6" >Decission Tree Esta I</td>
#     </tr>
#     <tr>
#       <th id="T_0e0c6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0e0c6_row2_col0" class="data row2 col0" >0.933670</td>
#       <td id="T_0e0c6_row2_col1" class="data row2 col1" >0.944767</td>
#       <td id="T_0e0c6_row2_col2" class="data row2 col2" >0.934130</td>
#       <td id="T_0e0c6_row2_col3" class="data row2 col3" >0.939418</td>
#       <td id="T_0e0c6_row2_col4" class="data row2 col4" >0.866139</td>
#       <td id="T_0e0c6_row2_col5" class="data row2 col5" >test</td>
#       <td id="T_0e0c6_row2_col6" class="data row2 col6" >Decision tree Esta II</td>
#     </tr>
#     <tr>
#       <th id="T_0e0c6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0e0c6_row3_col0" class="data row3 col0" >0.941687</td>
#       <td id="T_0e0c6_row3_col1" class="data row3 col1" >0.952718</td>
#       <td id="T_0e0c6_row3_col2" class="data row3 col2" >0.939950</td>
#       <td id="T_0e0c6_row3_col3" class="data row3 col3" >0.946291</td>
#       <td id="T_0e0c6_row3_col4" class="data row3 col4" >0.882516</td>
#       <td id="T_0e0c6_row3_col5" class="data row3 col5" >train</td>
#       <td id="T_0e0c6_row3_col6" class="data row3 col6" >Decision tree Esta II</td>
#     </tr>
#     <tr>
#       <th id="T_0e0c6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0e0c6_row4_col0" class="data row4 col0" >0.933670</td>
#       <td id="T_0e0c6_row4_col1" class="data row4 col1" >0.944767</td>
#       <td id="T_0e0c6_row4_col2" class="data row4 col2" >0.934130</td>
#       <td id="T_0e0c6_row4_col3" class="data row4 col3" >0.939418</td>
#       <td id="T_0e0c6_row4_col4" class="data row4 col4" >0.866139</td>
#       <td id="T_0e0c6_row4_col5" class="data row4 col5" >test</td>
#       <td id="T_0e0c6_row4_col6" class="data row4 col6" >Decision tree Sin Esta III</td>
#     </tr>
#     <tr>
#       <th id="T_0e0c6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0e0c6_row5_col0" class="data row5 col0" >0.941687</td>
#       <td id="T_0e0c6_row5_col1" class="data row5 col1" >0.952718</td>
#       <td id="T_0e0c6_row5_col2" class="data row5 col2" >0.939950</td>
#       <td id="T_0e0c6_row5_col3" class="data row5 col3" >0.946291</td>
#       <td id="T_0e0c6_row5_col4" class="data row5 col4" >0.882516</td>
#       <td id="T_0e0c6_row5_col5" class="data row5 col5" >train</td>
#       <td id="T_0e0c6_row5_col6" class="data row5 col6" >Decision tree Sin Esta III</td>
#     </tr>
#     <tr>
#       <th id="T_0e0c6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0e0c6_row6_col0" class="data row6 col0" >0.944526</td>
#       <td id="T_0e0c6_row6_col1" class="data row6 col1" >0.957261</td>
#       <td id="T_0e0c6_row6_col2" class="data row6 col2" >0.941263</td>
#       <td id="T_0e0c6_row6_col3" class="data row6 col3" >0.949194</td>
#       <td id="T_0e0c6_row6_col4" class="data row6 col4" >0.888116</td>
#       <td id="T_0e0c6_row6_col5" class="data row6 col5" >test</td>
#       <td id="T_0e0c6_row6_col6" class="data row6 col6" >Random Forest</td>
#     </tr>
#     <tr>
#       <th id="T_0e0c6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0e0c6_row7_col0" class="data row7 col0" >0.951215</td>
#       <td id="T_0e0c6_row7_col1" class="data row7 col1" >0.964254</td>
#       <td id="T_0e0c6_row7_col2" class="data row7 col2" >0.945796</td>
#       <td id="T_0e0c6_row7_col3" class="data row7 col3" >0.954936</td>
#       <td id="T_0e0c6_row7_col4" class="data row7 col4" >0.901770</td>
#       <td id="T_0e0c6_row7_col5" class="data row7 col5" >train</td>
#       <td id="T_0e0c6_row7_col6" class="data row7 col6" >Random Forest</td>
#     </tr>
#   </tbody>
# </table>

# %%
importancia_predictores = pd.DataFrame(
                            {'predictor': x_train.columns,
                             'importancia': bosque.feature_importances_}
                            )


# ordenamos de mayor a menor los resultados
importancia_predictores.sort_values(by=["importancia"], ascending=False, inplace = True)

# printeamos los resultados
print("Importancia de los predictores en el modelo")
print("-------------------------------------------")
importancia_predictores
# Out:
# Importancia de los predictores en el modelo
# -------------------------------------------
#             predictor  importancia
# 6             asiento     0.237335
# 11    entretenimiento     0.224113
# 13      reserva_linea     0.157119
# 12   asistencia_linea     0.089993
# 8       comida_bebida     0.028958
# 1             cliente     0.026709
# 0              genero     0.024427
# 3               viaje     0.022556
# 7         puntualidad     0.020912
# 17            checkin     0.018381
# 18           limpieza     0.018099
# 15  serv_habitaciones     0.016523
# 19     embarque_linea     0.015568
# 9     puerta_embarque     0.014229
# 14       serv_a_bordo     0.014198
# 4               clase     0.014141
# 10               wifi     0.013875
# 5           distancia     0.013213
# 16   gestion_equipaje     0.011634
# 20     retraso_salida     0.009024
# 2                edad     0.008993

# %%
plt.figure(figsize=(10,6))
sns.barplot(x = "importancia", y = "predictor", data = importancia_predictores, palette= qualitative_colors);
plt.show()

# %%
df_todos_resultados.to_pickle("../data/df_todos_resultados_sin_estand_con_outliers.pkl")
